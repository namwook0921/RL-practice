# %% [markdown]
# # GitHub Push Notebook (Colab)
# This notebook helps sync your Google Drive project folder to a GitHub repository.

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Step 2: Configure Git
# !git config --global user.name 'namwook0921'
# !git config --global user.email 'namwook0921@gmail.com'

# %%
import os
import getpass

# Prompt for GitHub PAT (invisible input)
token = getpass.getpass("Enter your GitHub PAT (Personal Access Token): ")
# Out:
# Enter your GitHub PAT (Personal Access Token): ··········

# %%
# %cd Myd
# Out:
# /

# %%
# !git clone https://github.com/namwook0921/RL-practice.git /content/RL-practice
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Cloning into '/content/RL-practice'...
# fatal: Unable to read current working directory: No such file or directory

# %%
# OPTIONAL: ONLY WHEN NEW FILES ARE ADDED
# Step 4: Copy files from Google Drive folder to GitHub repo folder
# Replace paths as neededa
# !rsync -av --exclude='*.gdoc' --exclude='*.png' /content/drive/MyDrive/RL_practice/ /content/RL-practice/
# Out:
# sending incremental file list
# created directory /content/RL-practice
# ./
# A2C_bipedal.ipynb
# A2C_cartpole.ipynb
# A2C_cartpole_vec_env.ipynb
# A2C_lunar_lander.ipynb
# DDQN_cartpole.ipynb
# DQN_cartpole.ipynb
# Dueling_DQN_cartpole.ipynb
# PPO_continuous.ipynb
# PPO_discrete.ipynb
# RL_A2C.ipynb
# github_push_colab.ipynb
# highway_env.ipynb
# sarsa_qlearn_comparison.ipynb
# gymnasium_tutorial/
# gymnasium_tutorial/create_a_custom_environment.ipynb
# gymnasium_tutorial/recording_agents.ipynb
# gymnasium_tutorial/training_an_agent.ipynb
#
# sent 12,273,298 bytes  received 378 bytes  791,850.06 bytes/sec
# total size is 12,269,086  speedup is 1.00

# %%
# Step 5: Commit and push
# %cd /content/RL-practice

commit_message = input("commit message: ")

authed_url = f"https://{token}@github.com/namwook0921/RL-practice.git"

# !git add .
# !git commit -m '{commit_message}'
# !git push {authed_url} main
# Out:
# /content/RL-practice
# commit message: multi agent RL
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
