# %% [markdown]
# # GitHub Push Notebook (Colab)
# This notebook helps sync your Google Drive project folder to a GitHub repository.

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Step 2: Configure Git
# !git config --global user.name 'namwook0921'
# !git config --global user.email 'namwook0921@gmail.com'

# %%
# %cd /content/RL-practice

# Start SSH agent and add key
# !eval `ssh-agent -s` && ssh-add ~/.ssh/id_rsa

# Disable host checking to avoid interactive prompt
# !mkdir -p ~/.ssh
# !echo -e "Host github.com\n\tStrictHostKeyChecking no\n" > ~/.ssh/config
# Out:
# Agent pid 22620
# Identity added: /root/.ssh/id_rsa (namwook0921@gmail.com)

# %%
#ONLY THE FIRST TIME
# Step 3: Clone your GitHub repo (replace YOUR_TOKEN and REPO info)

import os, getpass
if not os.path.exists("/content/RL-practice"):
    token = getpass.getpass("GitHub token: ")
    # !git clone https://{token}@github.com/namwook0921/RL-practice.git

os.path.exists("/content/RL-practice")
# Out:
# True

# %%
# OPTIONAL: ONLY WHEN NEW FILES ARE ADDED
# Step 4: Copy files from Google Drive folder to GitHub repo folder
# Replace paths as needed
# !rsync -av --exclude='*.gdoc' --exclude='*.png' "/content/drive/MyDrive/RL_practice/" "/content/RL-practice/"
# Out:
# sending incremental file list
# ./
# github_push_colab.ipynb
#
# sent 5,131 bytes  received 39 bytes  10,340.00 bytes/sec
# total size is 2,122,748  speedup is 410.59

# %%
# Step 5: Commit and push
# %cd /content/RL-practice

commit_message = input("commit message: ")

# !git add .
# !git commit -m '{commit_message}'
# !git push origin main
# Out:
# /content/RL-practice
# commit message: debugging A2C_lunar_lander
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# fatal: could not read Password for 'https://%7Btoken%7D@github.com': No such device or address

# %%
# !git remote set-url origin https://{token}@github.com/namwook0921/RL-practice.git


# !git push https://{token}@github.com/namwook0921/RL-practice.git
# Out:
# fatal: could not read Password for 'https://%7Btoken%7D@github.com': No such device or address

# %%
# !ssh-keygen -t rsa -b 4096 -C "namwook0921@gmail.com" -f ~/.ssh/id_rsa -N ""
# Out:
# Generating public/private rsa key pair.
# /root/.ssh/id_rsa already exists.
# Overwrite (y/n)? y
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:f4uZNi0cGh8HXEewzSCaabM2t7UObIYRPf4rxd1a5xw namwook0921@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |          . oo.  |
# |         = ..=.  |
# |        B.o...o  |
# |       . =o.     |
# |        S oo.. . |
# |       ..Bo++..E+|
# |        .=B*+  =o|
# |        .oBB.o. o|
# |         .+++    |
# +----[SHA256]-----+

# %%
# !cat ~/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... namwook0921@gmail.com

# %%
# !eval "$(ssh-agent -s)"
# !ssh-add ~/.ssh/id_rsa
# !mkdir -p ~/.ssh && echo -e "Host github.com\n\tStrictHostKeyChecking no\n" > ~/.ssh/config
# Out:
# Agent pid 22366
# Could not open a connection to your authentication agent.
